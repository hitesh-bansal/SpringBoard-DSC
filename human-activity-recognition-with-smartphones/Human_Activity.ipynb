# %%
import pandas as pd

# %%
df = pd.read_csv("train.csv")

# %%
df
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 0              0.288585          -0.020294          -0.132905
# 1              0.278419          -0.016411          -0.123520
# 2              0.279653          -0.019467          -0.113462
# 3              0.279174          -0.026201          -0.123283
# 4              0.276629          -0.016570          -0.115362
# 5              0.277199          -0.010098          -0.105137
# 6              0.279454          -0.019641          -0.110022
# 7              0.277432          -0.030488          -0.125360
# 8              0.277293          -0.021751          -0.120751
# 9              0.280586          -0.009960          -0.106065
# 10             0.276880          -0.012722          -0.103438
# 11             0.276228          -0.021441          -0.108202
# 12             0.278457          -0.020415          -0.112732
# 13             0.277175          -0.014713          -0.106756
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7352 entries, 0 to 7351
# Columns: 563 entries, tBodyAcc-mean()-X to Activity
# dtypes: float64(561), int64(1), object(1)
# memory usage: 31.6+ MB

# %%
df.columns
# Out:
# Index(['tBodyAcc-mean()-X', 'tBodyAcc-mean()-Y', 'tBodyAcc-mean()-Z',
#        'tBodyAcc-std()-X', 'tBodyAcc-std()-Y', 'tBodyAcc-std()-Z',
#        'tBodyAcc-mad()-X', 'tBodyAcc-mad()-Y', 'tBodyAcc-mad()-Z',
#        'tBodyAcc-max()-X',
#        ...
#        'fBodyBodyGyroJerkMag-kurtosis()', 'angle(tBodyAccMean,gravity)',
#        'angle(tBodyAccJerkMean),gravityMean)',
#        'angle(tBodyGyroMean,gravityMean)',
#        'angle(tBodyGyroJerkMean,gravityMean)', 'angle(X,gravityMean)',
#        'angle(Y,gravityMean)', 'angle(Z,gravityMean)', 'subject', 'Activity'],
#       dtype='object', length=563)

# %%
 cols = df.columns.tolist()

# %% [markdown]
# # Print the all the column names

# %%
cols
# Out:
# ['tBodyAcc-mean()-X',
#  'tBodyAcc-mean()-Y',
#  'tBodyAcc-mean()-Z',
#  'tBodyAcc-std()-X',
#  'tBodyAcc-std()-Y',
#  'tBodyAcc-std()-Z',
#  'tBodyAcc-mad()-X',
#  'tBodyAcc-mad()-Y',
#  'tBodyAcc-mad()-Z',
#  'tBodyAcc-max()-X',
#  'tBodyAcc-max()-Y',
#  'tBodyAcc-max()-Z',
#  'tBodyAcc-min()-X',
#  'tBodyAcc-min()-Y',
#  'tBodyAcc-min()-Z',
#  'tBodyAcc-sma()',
#  'tBodyAcc-energy()-X',
#  'tBodyAcc-energy()-Y',
#  'tBodyAcc-energy()-Z',
#  'tBodyAcc-iqr()-X',
#  'tBodyAcc-iqr()-Y',
#  'tBodyAcc-iqr()-Z',
#  'tBodyAcc-entropy()-X',
#  'tBodyAcc-entropy()-Y',
#  'tBodyAcc-entropy()-Z',
#  'tBodyAcc-arCoeff()-X,1',
#  'tBodyAcc-arCoeff()-X,2',
#  'tBodyAcc-arCoeff()-X,3',
#  'tBodyAcc-arCoeff()-X,4',
#  'tBodyAcc-arCoeff()-Y,1',
#  'tBodyAcc-arCoeff()-Y,2',
#  'tBodyAcc-arCoeff()-Y,3',
#  'tBodyAcc-arCoeff()-Y,4',
#  'tBodyAcc-arCoeff()-Z,1',
#  'tBodyAcc-arCoeff()-Z,2',
#  'tBodyAcc-arCoeff()-Z,3',
#  'tBodyAcc-arCoeff()-Z,4',
#  'tBodyAcc-correlation()-X,Y',
# ...

# %% [markdown]
# # Checking Is there any missing values

# %%
df.isnull().values.any()
# Out:
# False

# %%
import matplotlib.pyplot as plt

# %%
from matplotlib.lines import Line2D

# %%
df_STANDING = df.loc[df.Activity == 'STANDING']

# %%
df_STANDING.tail()
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 7195           0.274527          -0.032259          -0.110678
# 7196           0.270246          -0.067724          -0.147258
# 7197           0.274422          -0.021115          -0.096432
# 7198           0.274834          -0.014149          -0.080437
# 7199           0.277676           0.011021          -0.062292
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 7195         -0.990631         -0.687065         -0.885434         -0.991251
# 7196         -0.990453         -0.774064         -0.926984         -0.991050
# 7197         -0.993005         -0.907217         -0.937185         -0.994032
# 7198         -0.978700         -0.871865         -0.903318         -0.984797
# 7199         -0.958620         -0.815830         -0.849154         -0.971655
#
#       tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X    ...     \
# ...

# %%
df_SITTING = df.loc[df.Activity == 'SITTING']

# %%
df_SITTING.head()
# Out:
#     tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 27           0.144504           0.189263           0.062769         -0.904300
# 28           0.287252          -0.037455          -0.145974         -0.982915
# 29           0.279998          -0.019484          -0.105724         -0.992818
# 30           0.221847           0.034108          -0.123612         -0.814708
# 31          -0.041701           0.175102           0.025552         -0.758393
#
#     tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 27         -0.181937         -0.443151         -0.901100         -0.110813
# 28         -0.891605         -0.941438         -0.984418         -0.891373
# 29         -0.940350         -0.981493         -0.993092         -0.936927
# 30         -0.749418         -0.571899         -0.878682         -0.776895
# 31         -0.586537         -0.439110         -0.774118         -0.555350
#
# ...

# %%
#WALKING, WALKING_UPSTAIRS, WALKING_DOWNSTAIRS, SITTING, STANDING, LAYING
df_WALKING = df.loc[df.Activity == 'WALKING']

# %%
df_WALKING.head()
# Out:
#     tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 78           0.282022          -0.037696          -0.134897         -0.328280
# 79           0.255841          -0.064550          -0.095186         -0.229207
# 80           0.254867           0.003815          -0.123658         -0.275158
# 81           0.343370          -0.014446          -0.167377         -0.229924
# 82           0.276240          -0.029638          -0.142616         -0.226577
#
#     tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 78         -0.137153         -0.189086         -0.404875         -0.176791
# 79          0.016506         -0.260311         -0.276764          0.009066
# 80          0.013080         -0.284371         -0.341341         -0.026013
# 81          0.173911         -0.213388         -0.282882          0.144693
# 82          0.164288         -0.122545         -0.239526          0.140287
#
# ...

# %%
df_WALKING_UPSTAIRS = df.loc[df.Activity == 'WALKING_UPSTAIRS']

# %%
df_WALKING_UPSTAIRS.head()
# Out:
#      tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 150           0.183604          -0.076559          -0.046956
# 151           0.279183          -0.036966          -0.133604
# 152           0.301162          -0.001759          -0.106830
# 153           0.293411          -0.018715          -0.066159
# 154           0.230310           0.002174          -0.043103
#
#      tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 150         -0.367516         -0.099161          0.020546         -0.412729
# 151         -0.359032         -0.124112         -0.102868         -0.394230
# 152         -0.362666          0.001220         -0.111538         -0.400837
# 153         -0.368157          0.095663         -0.019262         -0.430579
# 154         -0.335254         -0.020444          0.031210         -0.398985
#
#      tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X        ...         \
# ...

# %%
df_WALKING_DOWNSTAIRS = df.loc[df.Activity == 'WALKING_DOWNSTAIRS']

# %%
df_WALKING_DOWNSTAIRS.head()
# Out:
#      tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 125           0.358455           0.017975          -0.084159
# 126           0.301715          -0.007049          -0.093681
# 127           0.281552          -0.016110          -0.140093
# 128           0.273956          -0.022899          -0.127256
# 129           0.299957           0.014082          -0.082310
#
#      tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 125         -0.171988         -0.188332         -0.399555         -0.218408
# 126         -0.040143         -0.141421         -0.325831         -0.079918
# 127         -0.094665         -0.007348         -0.347492         -0.151053
# 128         -0.133382          0.132265         -0.336174         -0.211594
# 129          0.069268          0.057800         -0.235050         -0.041806
#
#      tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X         ...          \
# ...

# %%
df_LAYING = df.loc[df.Activity == 'LAYING']

# %%
df_LAYING.head()
# Out:
#     tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 51           0.403474          -0.015074          -0.118167         -0.914811
# 52           0.278373          -0.020561          -0.096825         -0.984883
# 53           0.276555          -0.017869          -0.107621         -0.994195
# 54           0.279575          -0.017276          -0.109481         -0.996135
# 55           0.276527          -0.016819          -0.107983         -0.996775
#
#     tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 51         -0.895231         -0.891748         -0.917696         -0.924624
# 52         -0.991118         -0.982112         -0.987985         -0.990362
# 53         -0.996372         -0.995615         -0.994901         -0.996360
# 54         -0.995812         -0.998689         -0.996393         -0.995474
# 55         -0.997256         -0.995422         -0.997167         -0.997108
#
# ...

# %%
df.plot(x = 'Activity',y = 'tBodyAcc-mean()-X', figsize= (15,15), grid=True, title="tBodyAcc-mean()-X")

# %%
df.plot(x = 'Activity',y = ['tBodyAcc-mean()-X','tBodyAcc-mean()-Y','tBodyAcc-mean()-Z'], figsize= (15,15), grid=True, title="tBodyAcc-mean()-X VS tBodyAcc-mean()-Y VS tBodyAcc-mean()-Z")

# %%
df.plot(x = 'Activity',y = ['tBodyAcc-std()-X','tBodyAcc-std()-Y','tBodyAcc-std()-Z'], figsize= (15,15),grid=True, title="tBodyAcc-std()-X VS tBodyAcc-std()-Y VS tBodyAcc-std()-Z")

# %%
df_SITTING.plot(x = 'tBodyAcc-std()-X' , y = 'tBodyAcc-std()-Z', grid=True)

# %%
df_SITTING.plot(x = 'Activity',y = 'tBodyAcc-mean()-X', grid=True, title="SITTING")
df_STANDING.plot(x = 'Activity',y = 'tBodyAcc-mean()-X', grid=True, title="STANDING")
df_LAYING.plot(x = 'Activity',y = 'tBodyAcc-mean()-X', grid=True, title="LAYING")
df_WALKING.plot(x = 'Activity',y = 'tBodyAcc-mean()-X', grid=True, title="WALKING")
df_WALKING_UPSTAIRS.plot(x = 'Activity',y = 'tBodyAcc-mean()-X', grid=True, title="WALKING_UPSTAIRS")
df_WALKING_DOWNSTAIRS.plot(x = 'Activity',y = 'tBodyAcc-mean()-X', grid=True, title="WALKING_DOWNSTAIRS")

# %%
df_SITTING.plot(x = 'Activity',y = 'tBodyAcc-std()-X', grid=True, title="SITTING")
df_STANDING.plot(x = 'Activity',y = 'tBodyAcc-std()-X', grid=True, title="STANDING")
df_LAYING.plot(x = 'Activity',y = 'tBodyAcc-std()-X', grid=True, title="LAYING")
df_WALKING.plot(x = 'Activity',y = 'tBodyAcc-std()-X', grid=True, title="WALKING")
df_WALKING_UPSTAIRS.plot(x = 'Activity',y = 'tBodyAcc-std()-X', grid=True, title="WALKING_UPSTAIRS")
df_WALKING_DOWNSTAIRS.plot(x = 'Activity',y = 'tBodyAcc-std()-X', grid=True, title="WALKING_DOWNSTAIRS")

# %%
df_SITTING.plot(x = 'Activity',y = 'tBodyAcc-mad()-X', grid=True, title="SITTING")
df_STANDING.plot(x = 'Activity',y = 'tBodyAcc-mad()-X', grid=True, title="STANDING")
df_LAYING.plot(x = 'Activity',y = 'tBodyAcc-mad()-X', grid=True, title="LAYING")
df_WALKING.plot(x = 'Activity',y = 'tBodyAcc-mad()-X', grid=True, title="WALKING")
df_WALKING_UPSTAIRS.plot(x = 'Activity',y = 'tBodyAcc-mad()-X', grid=True, title="WALKING_UPSTAIRS")
df_WALKING_DOWNSTAIRS.plot(x = 'Activity',y = 'tBodyAcc-mad()-X', grid=True, title="WALKING_DOWNSTAIRS")

# %%
df_SITTING.plot(x = 'Activity',y = 'tBodyAcc-sma()', grid=True, title="SITTING")
df_STANDING.plot(x = 'Activity',y = 'tBodyAcc-sma()', grid=True, title="STANDING")
df_LAYING.plot(x = 'Activity',y = 'tBodyAcc-sma()', grid=True, title="LAYING")
df_WALKING.plot(x = 'Activity',y = 'tBodyAcc-sma()', grid=True, title="WALKING")
df_WALKING_UPSTAIRS.plot(x = 'Activity',y = 'tBodyAcc-sma()', grid=True, title="WALKING_UPSTAIRS")
df_WALKING_DOWNSTAIRS.plot(x = 'Activity',y = 'tBodyAcc-sma()', grid=True, title="WALKING_DOWNSTAIRS")

# %%
df_SITTING.plot(x = 'Activity',y = 'tBodyAcc-energy()-X', grid=True, title="SITTING")
df_STANDING.plot(x = 'Activity',y = 'tBodyAcc-energy()-X', grid=True, title="STANDING")
df_LAYING.plot(x = 'Activity',y = 'tBodyAcc-energy()-X', grid=True, title="LAYING")
df_WALKING.plot(x = 'Activity',y = 'tBodyAcc-energy()-X', grid=True, title="WALKING")
df_WALKING_UPSTAIRS.plot(x = 'Activity',y = 'tBodyAcc-energy()-X', grid=True, title="WALKING_UPSTAIRS")
df_WALKING_DOWNSTAIRS.plot(x = 'Activity',y = 'tBodyAcc-energy()-X', grid=True, title="WALKING_DOWNSTAIRS")

# %%
df_SITTING.plot(x = 'Activity',y = 'tBodyAcc-iqr()-X', grid=True, title="SITTING")
df_STANDING.plot(x = 'Activity',y = 'tBodyAcc-iqr()-X', grid=True, title="STANDING")
df_LAYING.plot(x = 'Activity',y = 'tBodyAcc-iqr()-X', grid=True, title="LAYING")
df_WALKING.plot(x = 'Activity',y = 'tBodyAcc-iqr()-X', grid=True, title="WALKING")
df_WALKING_UPSTAIRS.plot(x = 'Activity',y = 'tBodyAcc-iqr()-X', grid=True, title="WALKING_UPSTAIRS")
df_WALKING_DOWNSTAIRS.plot(x = 'Activity',y = 'tBodyAcc-iqr()-X', grid=True, title="WALKING_DOWNSTAIRS")

# %%
df_SITTING.plot(x = 'Activity',y = 'tBodyAcc-entropy()-X', grid=True, title="SITTING")
df_STANDING.plot(x = 'Activity',y = 'tBodyAcc-entropy()-X', grid=True, title="STANDING")
df_LAYING.plot(x = 'Activity',y = 'tBodyAcc-entropy()-X', grid=True, title="LAYING")
df_WALKING.plot(x = 'Activity',y = 'tBodyAcc-entropy()-X', grid=True, title="WALKING")
df_WALKING_UPSTAIRS.plot(x = 'Activity',y = 'tBodyAcc-entropy()-X', grid=True, title="WALKING_UPSTAIRS")
df_WALKING_DOWNSTAIRS.plot(x = 'Activity',y = 'tBodyAcc-entropy()-X', grid=True, title="WALKING_DOWNSTAIRS")

# %%
df_SITTING.plot(x = 'Activity',y = 'tBodyAcc-arCoeff()-X,1', grid=True, title="SITTING")
df_STANDING.plot(x = 'Activity',y = 'tBodyAcc-arCoeff()-X,1', grid=True, title="STANDING")
df_LAYING.plot(x = 'Activity',y = 'tBodyAcc-arCoeff()-X,1', grid=True, title="LAYING")
df_WALKING.plot(x = 'Activity',y = 'tBodyAcc-arCoeff()-X,1', grid=True, title="WALKING")
df_WALKING_UPSTAIRS.plot(x = 'Activity',y = 'tBodyAcc-arCoeff()-X,1', grid=True, title="WALKING_UPSTAIRS")
df_WALKING_DOWNSTAIRS.plot(x = 'Activity',y = 'tBodyAcc-arCoeff()-X,1', grid=True, title="WALKING_DOWNSTAIRS")

# %%
df_SITTING.plot(x = 'Activity',y = 'tBodyAcc-correlation()-X,Y', grid=True, title="SITTING")
df_STANDING.plot(x = 'Activity',y = 'tBodyAcc-correlation()-X,Y', grid=True, title="STANDING")
df_LAYING.plot(x = 'Activity',y = 'tBodyAcc-correlation()-X,Y', grid=True, title="LAYING")
df_WALKING.plot(x = 'Activity',y = 'tBodyAcc-correlation()-X,Y', grid=True, title="WALKING")
df_WALKING_UPSTAIRS.plot(x = 'Activity',y = 'tBodyAcc-correlation()-X,Y', grid=True, title="WALKING_UPSTAIRS")
df_WALKING_DOWNSTAIRS.plot(x = 'Activity',y = 'tBodyAcc-correlation()-X,Y', grid=True, title="WALKING_DOWNSTAIRS")

# %%
df_SITTING.plot(x = 'Activity',y = 'tGravityAcc-mean()-X', grid=True, title="SITTING")
df_STANDING.plot(x = 'Activity',y = 'tGravityAcc-mean()-X', grid=True, title="STANDING")
df_LAYING.plot(x = 'Activity',y = 'tGravityAcc-mean()-X', grid=True, title="LAYING")
df_WALKING.plot(x = 'Activity',y = 'tGravityAcc-mean()-X', grid=True, title="WALKING")
df_WALKING_UPSTAIRS.plot(x = 'Activity',y = 'tGravityAcc-mean()-X', grid=True, title="WALKING_UPSTAIRS")
df_WALKING_DOWNSTAIRS.plot(x = 'Activity',y = 'tGravityAcc-mean()-X', grid=True, title="WALKING_DOWNSTAIRS")

# %%
df_SITTING.plot(x = 'Activity',y = 'tBodyAccJerk-std()-X', grid=True, title="SITTING")
df_STANDING.plot(x = 'Activity',y = 'tBodyAccJerk-std()-X', grid=True, title="STANDING")
df_LAYING.plot(x = 'Activity',y = 'tBodyAccJerk-std()-X', grid=True, title="LAYING")
df_WALKING.plot(x = 'Activity',y = 'tBodyAccJerk-std()-X', grid=True, title="WALKING")
df_WALKING_UPSTAIRS.plot(x = 'Activity',y = 'tBodyAccJerk-std()-X', grid=True, title="WALKING_UPSTAIRS")
df_WALKING_DOWNSTAIRS.plot(x = 'Activity',y = 'tBodyAccJerk-std()-X', grid=True, title="WALKING_DOWNSTAIRS")

# %%
fig = plt.figure(figsize=(12,12)) # define plot area
ax = fig.gca() # define axis    
df[['Activity','tBodyAcc-std()-X']].boxplot(by = 'Activity', ax = ax) # Use the plot.bar method on the new data frame
ax.set_title('Box plots of tBodyAcc-std()-X') # Give the plot a main title
ax.set_xlabel('Activity') # Set text for the x axis
ax.set_ylabel('values')# Set text for y axis
# Out:
# Text(0,0.5,'values')

# %%
cols
# Out:
# ['tBodyAcc-mean()-X',
#  'tBodyAcc-mean()-Y',
#  'tBodyAcc-mean()-Z',
#  'tBodyAcc-std()-X',
#  'tBodyAcc-std()-Y',
#  'tBodyAcc-std()-Z',
#  'tBodyAcc-mad()-X',
#  'tBodyAcc-mad()-Y',
#  'tBodyAcc-mad()-Z',
#  'tBodyAcc-max()-X',
#  'tBodyAcc-max()-Y',
#  'tBodyAcc-max()-Z',
#  'tBodyAcc-min()-X',
#  'tBodyAcc-min()-Y',
#  'tBodyAcc-min()-Z',
#  'tBodyAcc-sma()',
#  'tBodyAcc-energy()-X',
#  'tBodyAcc-energy()-Y',
#  'tBodyAcc-energy()-Z',
#  'tBodyAcc-iqr()-X',
#  'tBodyAcc-iqr()-Y',
#  'tBodyAcc-iqr()-Z',
#  'tBodyAcc-entropy()-X',
#  'tBodyAcc-entropy()-Y',
#  'tBodyAcc-entropy()-Z',
#  'tBodyAcc-arCoeff()-X,1',
#  'tBodyAcc-arCoeff()-X,2',
#  'tBodyAcc-arCoeff()-X,3',
#  'tBodyAcc-arCoeff()-X,4',
#  'tBodyAcc-arCoeff()-Y,1',
#  'tBodyAcc-arCoeff()-Y,2',
#  'tBodyAcc-arCoeff()-Y,3',
#  'tBodyAcc-arCoeff()-Y,4',
#  'tBodyAcc-arCoeff()-Z,1',
#  'tBodyAcc-arCoeff()-Z,2',
#  'tBodyAcc-arCoeff()-Z,3',
#  'tBodyAcc-arCoeff()-Z,4',
#  'tBodyAcc-correlation()-X,Y',
# ...

# %%
fig = plt.figure(figsize=(12,12)) 
ax = fig.gca()
df[['Activity','angle(X,gravityMean)']].boxplot(by = 'Activity', ax = ax)
ax.set_title('angle(X,gravityMean)')
ax.set_xlabel('Activity')
ax.set_ylabel('values')
# Out:
# Text(0,0.5,'values')
