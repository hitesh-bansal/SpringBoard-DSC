# %%
import pandas as pd

# %%
df_Country_code_Mapping = pd.read_csv("Country-Code-Mapping.csv")

# %%
df_Country_code_Mapping
# Out:
#      Value                           Label
# 0        4                     Afghanistan
# 1        6                         Albania
# 2        7                         Algeria
# 3        8                  American Samoa
# 4        9                         Andorra
# 5       10                          Angola
# 6       12                       Argentina
# 7       13                         Armenia
# 8       14             Asia/Pacific Region
# 9       15                       Australia
# 10      16                         Austria
# 11      17                      Azerbaijan
# 12      18                      Bangladesh
# 13      19                        Barbados
# 14      21                         Belarus
# 15      22                         Belgium
# 16      23                          Belize
# 17      24                         Bermuda
# 18      25                         Bolivia
# 19      26          Bosnia and Herzegovina
# 20      27                          Brazil
# ...
